# %%
import json
import time
from selenium import webdriver
import pandas as pd
import matplotlib.pyplot as plt
from markdownify import markdownify

# %%
def scrape_job_links(driver,url,link_css_selector):
    page = 0
    
    job_links = []
    
    while True:
        
        page+=1
        
        driver.get(url.format(page_number=page))
        
        print(f'scraping {driver.current_url}')
        
        job_link_elements = driver.find_elements_by_css_selector('div.job div.job-title a')
        
        if len(job_link_elements) == 0:
            break
        else:
            print(f'found {len(job_link_elements)} urls')
            job_links+=[job_link_element.get_attribute('href') for job_link_element in job_link_elements]
    
    return job_links

def scrape_job_details(driver,url):
    driver.get(url)
    
    job = {}
    
    df_job = json.loads(driver.find_elements_by_css_selector('script#jobPostingSchema')[0].get_attribute('innerHTML'))
    
    job['url'] = df_job['url']
    job['title'] = df_job['title']
    job['job_type'] = df_job['employmentType']
    job['job_description_html'] = df_job['description']
    
    df_hiring_org = pd.json_normalize(df_job['hiringOrganization'])
    
    job['hiring_organization'] = df_hiring_org['name'][0]
    

    return job

# %%
try:
    driver = webdriver.Firefox()

    url = "https://www.cwjobs.co.uk/jobs/data-scientist?page={page_number}"

    link_css_selector = 'div.job div.job-title a'

    job_details = []

    job_links = scrape_job_links(driver,url,link_css_selector)


    for job_link in job_links:
        job_details.append(scrape_job_details(driver,job_link))

except:
    raise
    
finally:    
    driver.close()
# Out:
# scraping https://www.cwjobs.co.uk/jobs/data-scientist?page=1
# found 20 urls
# scraping https://www.cwjobs.co.uk/jobs/data-scientist?page=2
# found 20 urls
# scraping https://www.cwjobs.co.uk/jobs/data-scientist?page=3
# found 20 urls
# scraping https://www.cwjobs.co.uk/jobs/data-scientist?page=4
# found 13 urls
# scraping https://www.cwjobs.co.uk/jobs/data-scientist?page=5

# %%
df_job_details = pd.DataFrame(job_details)

# %%
df_job_details.groupby('hiring_organization').count()
# Out:
#                                          url  title  job_type  \
# hiring_organization
# ADLIB Recruitment                          1      1         1
# ANSON MCCADE                               3      3         3
# Amber Resourcing                           4      4         4
# Amicus Recruitment Limited                 3      3         3
# CGI                                        1      1         1
# CPS Group UK                               2      2         2
# Capita                                     1      1         1
# Careerwise UK Limited                      3      3         3
# Client Server                              5      5         5
# Deloitte                                   1      1         1
# Digital Waffle                             1      1         1
# Experis Ltd                                2      2         2
# HAYS INFORMATION TECHNOLOGY                2      2         2
# Harrington Starr                           1      1         1
# IET SA                                     1      1         1
# Integrity Recruitment Solutions Limited    1      1         1
# Intouch Games ltd                          1      1         1
# Johnson Controls                           1      1         1
# Joseph Harry Ltd                           4      4         4
# La Fosse Associates                        1      1         1
# Lexis-Nexis Europe Ltd                     2      2         2
# Lorien Resourcing                          1      1         1
# Method-Resourcing                          1      1         1
# Nationwide People Ltd                      1      1         1
# Networking People                          1      1         1
# Oliver Bernard                             2      2         2
# Optima Connections                         1      1         1
# Placing Leads Limited                      1      1         1
# RMIT Professional Resources AG             2      2         2
# Real Time Consultants                      1      1         1
# RecruitmentRevolution.com Limited          1      1         1
# Revoco                                     1      1         1
# Searchability                              5      5         5
# Spencer Rose                               1      1         1
# Spring Technology                          1      1         1
# Tec Partners                               1      1         1
# Totaljobs Group                            3      3         3
# Understanding Recruitment                  6      6         6
# onezeero.                                  2      2         2
#
#                                          job_description_html
# hiring_organization
# ADLIB Recruitment                                           1
# ANSON MCCADE                                                3
# Amber Resourcing                                            4
# Amicus Recruitment Limited                                  3
# CGI                                                         1
# CPS Group UK                                                2
# Capita                                                      1
# Careerwise UK Limited                                       3
# Client Server                                               5
# Deloitte                                                    1
# Digital Waffle                                              1
# Experis Ltd                                                 2
# HAYS INFORMATION TECHNOLOGY                                 2
# Harrington Starr                                            1
# IET SA                                                      1
# Integrity Recruitment Solutions Limited                     1
# Intouch Games ltd                                           1
# Johnson Controls                                            1
# Joseph Harry Ltd                                            4
# La Fosse Associates                                         1
# Lexis-Nexis Europe Ltd                                      2
# Lorien Resourcing                                           1
# Method-Resourcing                                           1
# Nationwide People Ltd                                       1
# Networking People                                           1
# Oliver Bernard                                              2
# Optima Connections                                          1
# Placing Leads Limited                                       1
# RMIT Professional Resources AG                              2
# Real Time Consultants                                       1
# RecruitmentRevolution.com Limited                           1
# Revoco                                                      1
# Searchability                                               5
# Spencer Rose                                                1
# Spring Technology                                           1
# Tec Partners                                                1
# Totaljobs Group                                             3
# Understanding Recruitment                                   6
# onezeero.                                                   2
